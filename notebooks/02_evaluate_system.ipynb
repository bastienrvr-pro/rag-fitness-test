# %% [markdown]
# # 📊 RAG FITNESS - SYSTEM EVALUATION
#
# **Purpose:** Evaluate retrieval quality and system performance
#
# **Input:** Golden Dataset (20 question-answer pairs)
#
# **Output:** Metrics report (Recall@5, MRR, Precision@5)
#
# **Run time:** ~5 minutes
#
# ---
#
# ## 📋 Evaluation Strategy
#
# **Retrieval Metrics (Automated):**
# - Recall@5: Is the correct document in top 5?
# - MRR: Average position of correct document
# - Precision@5: % of relevant docs in top 5
#
# **Generation Quality (Manual):**
# - Sample 5 answers and inspect manually
# - LLM-as-Judge with small models is NOT reliable
#
# ---

# %% [markdown]
# ## 📦 STEP 1: Setup

# %%
import sys
from pathlib import Path
import json  # ← AJOUTER CETTE LIGNE
from typing import List, Dict
from datetime import datetime

# Add src to path
sys.path.insert(0, str(Path.cwd().parent / "src"))

# Import
from retriever import Retriever
from chatbot import RAGChatbot

print("✅ Imports successful")
# Out:
# ✅ Imports successful

# %% [markdown]
# ## 📂 STEP 2: Load Golden Dataset

# %%
# Load Golden Dataset
golden_dataset_path = Path.cwd().parent / "data" / "golden_dataset.json"

with open(golden_dataset_path, 'r', encoding='utf-8') as f:
    golden_dataset = json.load(f)

print(f"📚 Golden Dataset loaded")
print(f"   Total questions: {len(golden_dataset)}")

# Count by category
from collections import Counter
categories = [item['category'] for item in golden_dataset]
cat_counts = Counter(categories)

print(f"\n📊 Breakdown by category:")
for cat, count in cat_counts.items():
    print(f"   {cat}: {count}")
# Out:
# 📚 Golden Dataset loaded
#    Total questions: 20
#
# 📊 Breakdown by category:
#    nutrition: 7
#    rom: 5
#    volume: 5
#    out_of_scope: 3

# %% [markdown]
# ## 🔧 STEP 3: Initialize Retriever

# %%
print("🔧 Initializing retriever...\n")

retriever = Retriever()

print("\n✅ Retriever ready")
# Out:
# 🔧 Initializing retriever...
#
# 🔧 Initializing Retriever...
#    📥 Loading embedding model: BAAI/bge-large-en-v1.5
#    💾 Connecting to ChromaDB: c:\RAG-Fitness-Test\data\processed\chroma_db
#    ✅ Collection 'fitness_knowledge_base': 1728 documents
#    🔤 Initializing BM25 index...
#       ✅ BM25 indexed: 1728 documents
#    🎯 Loading Cross-Encoder for re-ranking...
#       ✅ Cross-Encoder loaded
#
# ✅ Retriever ready (Hybrid Search enabled)
#
# ✅ Retriever ready

# %% [markdown]
# ## 📊 STEP 4: Evaluate Retriever
#
# **Metrics:**
# - **Recall@5**: Is the correct document in top 5 results?
# - **MRR (Mean Reciprocal Rank)**: Average position of correct document
# - **Precision@5**: % of relevant documents in top 5

# %%
print("📊 EVALUATING RETRIEVER\n")
print("=" * 80)

# Metrics storage
recall_at_5 = []
reciprocal_ranks = []
precision_at_5 = []

# Filter out "out of scope" questions
in_scope_questions = [
    item for item in golden_dataset 
    if item.get('category') != 'out_of_scope'
]

print(f"Evaluating {len(in_scope_questions)} in-scope questions...\n")

for i, item in enumerate(in_scope_questions, 1):
    query = item['question']
    relevant_docs = item.get('relevant_docs', [])
    
    # Skip if no relevant docs specified
    if not relevant_docs:
        print(f"{i:2d}. ⚠️ {query[:60]}... (no relevant_docs)")
        continue
    
    # Retrieve with hybrid search
    results = retriever.hybrid_search(
        query=query,
        top_k=5,
        retrieve_k=20,
        alpha=0.5
    )
    
    # Extract sources
    retrieved_sources = [doc['source'] for doc in results]
    
    # Calculate Recall@5 (is ANY relevant doc in top 5?)
    found = any(
        any(rel_doc in source for source in retrieved_sources)
        for rel_doc in relevant_docs
    )
    recall_at_5.append(1 if found else 0)
    
    # Calculate MRR (position of FIRST relevant doc)
    rank = None
    for j, source in enumerate(retrieved_sources, 1):
        if any(rel_doc in source for rel_doc in relevant_docs):
            rank = j
            break
    
    if rank:
        reciprocal_ranks.append(1.0 / rank)
    else:
        reciprocal_ranks.append(0.0)
    
    # Calculate Precision@5
    relevant_in_top5 = sum(
        1 for source in retrieved_sources 
        if any(rel_doc in source for rel_doc in relevant_docs)
    )
    precision_at_5.append(relevant_in_top5 / 5.0)
    
    # Progress
    status = "✅" if found else "❌"
    print(f"{i:2d}. {status} {query[:60]}...")
    if found and rank:
        print(f"     Found: {retrieved_sources[rank-1]} (position {rank})")
    elif not found:
        print(f"     Expected: {relevant_docs[0]}")
        print(f"     Got: {retrieved_sources[0]}")

# Calculate metrics
recall_5 = sum(recall_at_5) / len(recall_at_5) * 100
mrr = sum(reciprocal_ranks) / len(reciprocal_ranks)
precision_5 = sum(precision_at_5) / len(precision_at_5) * 100

print("\n" + "=" * 80)
print("\n📊 RETRIEVER METRICS\n")
print(f"Recall@5:    {recall_5:.1f}%")
print(f"MRR:         {mrr:.3f} (avg position: {1/mrr if mrr > 0 else 'N/A':.1f})")
print(f"Precision@5: {precision_5:.1f}%")
print(f"\nEvaluated:   {len(in_scope_questions)} questions")

# Interpretation
print("\n📈 INTERPRETATION\n")
if recall_5 >= 80:
    print("   ✅ Recall > 80%: EXCELLENT")
elif recall_5 >= 60:
    print("   ⚠️ Recall 60-80%: ACCEPTABLE")
else:
    print("   ❌ Recall < 60%: NEEDS IMPROVEMENT")

print("=" * 80)
# Out:
# 📊 EVALUATING RETRIEVER
#
# ================================================================================
# Evaluating 17 in-scope questions...
#
#  1. ✅ What is the optimal protein intake for muscle hypertrophy in...
#      Found: issn_protein_position.pdf (position 2)
#  2. ❌ How much protein per meal for optimal muscle protein synthes...
#      Expected: issn_protein_position.pdf
#      Got: schoenfeld_rom_hypertrophy.pdf
#  3. ✅ Is creatine supplementation effective for muscle growth?...
#      Found: helms_bodybuilding_nutrition.pdf (position 1)
#  4. ✅ Should protein intake be higher during a caloric deficit?...
#      Found: helms_bodybuilding_nutrition.pdf (position 1)
#  5. ✅ What is the protein timing window after training?...
#      Found: issn_protein_position.pdf (position 5)
#  6. ✅ Are BCAAs necessary if protein intake is adequate?...
#      Found: issn_protein_position.pdf (position 1)
#  7. ✅ What supplements are most effective for muscle hypertrophy?...
#      Found: helms_bodybuilding_nutrition.pdf (position 1)
#  8. ✅ Does full range of motion improve muscle hypertrophy compare...
#      Found: schoenfeld_rom_hypertrophy.pdf (position 1)
#  9. ✅ Are there any exceptions where partial ROM is better than fu...
#      Found: schoenfeld_rom_hypertrophy.pdf (position 1)
# 10. ✅ What is the mechanism behind full ROM producing more hypertr...
#      Found: schoenfeld_rom_hypertrophy.pdf (position 1)
# 11. ✅ Should I use full ROM on all exercises?...
#      Found: schoenfeld_rom_hypertrophy.pdf (position 1)
# 12. ✅ Does range of motion affect strength and hypertrophy differe...
#      Found: schoenfeld_rom_hypertrophy.pdf (position 1)
# 13. ✅ What is the optimal training volume for muscle hypertrophy?...
#      Found: schoenfeld_rom_hypertrophy.pdf (position 1)
# 14. ✅ How many sets per exercise should I do for hypertrophy?...
#      Found: bernardez_training_variables.pdf (position 1)
# 15. ✅ Is there a point where more volume stops helping muscle grow...
#      Found: bernardez_training_variables.pdf (position 2)
# 16. ✅ What is the optimal training frequency for hypertrophy?...
#      Found: schoenfeld_rom_hypertrophy.pdf (position 1)
# 17. ❌ Should I train to failure for maximum muscle growth?...
#      Expected: bernardez_training_variables.pdf
#      Got: schoenfeld_rom_hypertrophy.pdf
#
# ================================================================================
#
# 📊 RETRIEVER METRICS
#
# Recall@5:    88.2%
# MRR:         0.776 (avg position: 1.3)
# Precision@5: 69.4%
#
# Evaluated:   17 questions
#
# 📈 INTERPRETATION
#
#    ✅ Recall > 80%: EXCELLENT
# ================================================================================

# %% [markdown]
# ## 🤖 STEP 5: Test Generator (Sample Answers)
#
# **Manual inspection is more reliable than LLM-as-Judge**

# %%
print("🤖 TESTING GENERATOR\n")
print("=" * 80)

# Initialize chatbot
print("Initializing chatbot...")
chatbot = RAGChatbot()

# Sample 5 questions for manual inspection
import random
sample_questions = random.sample(in_scope_questions, min(5, len(in_scope_questions)))

print(f"\nTesting {len(sample_questions)} sample questions...\n")

for i, item in enumerate(sample_questions, 1):
    print("\n" + "─" * 80)
    print(f"\n📝 QUESTION {i}\n")
    print(f"Q: {item['question']}")
    print(f"\nRelevant docs: {item['relevant_docs']}")
    print(f"Category: {item['category']}")
    
    # Generate answer
    result = chatbot.answer(
        question=item['question'],
        doc_type="scientific_paper",  # Only scientific papers
        top_k=5
    )
    
    print(f"\n💬 ANSWER:\n")
    print(result['answer'])
    
    print(f"\n📚 SOURCES USED:\n")
    for j, source in enumerate(result['sources'][:3], 1):
        print(f"{j}. {source['source']} (page {source['page']})")
        print(f"   Score: {source['score']:.3f}")

print("\n" + "=" * 80)
print("\n✅ Sample answers generated")
print("\n👀 MANUAL INSPECTION:")
print("   Please review the answers above and assess:")
print("   - Faithfulness: Does it only use info from sources?")
print("   - Completeness: Does it answer the question fully?")
print("   - Relevance: Is it concise and useful?")
# Out:
# 🤖 TESTING GENERATOR
#
# ================================================================================
# Initializing chatbot...
#
# ================================================================================
# 🤖 INITIALIZING RAG CHATBOT
# ================================================================================
# 🔧 Initializing Retriever...
#    📥 Loading embedding model: BAAI/bge-large-en-v1.5
#    💾 Connecting to ChromaDB: c:\RAG-Fitness-Test\data\processed\chroma_db
#    ✅ Collection 'fitness_knowledge_base': 1728 documents
#    🔤 Initializing BM25 index...
#       ✅ BM25 indexed: 1728 documents
#    🎯 Loading Cross-Encoder for re-ranking...
#       ✅ Cross-Encoder loaded
#
# ✅ Retriever ready (Hybrid Search enabled)
#
# 🔍 Checking Ollama (http://localhost:11434)...
#    ✅ Ollama is available
#    🧠 Model: llama3.2:3b
#    🌡️ Temperature: 0.1
#    📏 Max tokens: 256
#
# ✅ Chatbot ready!
# ================================================================================
#
#
# Testing 5 sample questions...
#
#
# ────────────────────────────────────────────────────────────────────────────────
#
# 📝 QUESTION 1
#
# Q: What is the mechanism behind full ROM producing more hypertrophy?
#
# Relevant docs: ['schoenfeld_rom_hypertrophy.pdf']
# Category: rom
#
# 💬 ANSWER:
#
# According to Schoenfeld's research, the mechanism behind full ROM producing more hypertrophy lies in the differential activation of muscles throughout the range of motion. Training at longer muscle lengths, where the muscle is in a stretched position, promotes greater hypertrophic adaptations (McMahon et al., 2012; Pinto et al., 2011). This may be due to increased time under tension and mechanical tension, leading to enhanced muscle protein synthesis and growth.
#
# Schoenfeld suggests that this differential activation is responsible for the increased magnitude of variance in hypertrophy between full ROM and partial ROM training (Schoenfeld, 2016, p. 121). The stretched position appears to elicit a greater activation of the slow-twitch fibers, which are more resistant to fatigue and require longer time under tension to be stimulated for growth.
#
# In contrast, partial ROM training tends to activate the fast-twitch fibers, which are more fatigue-resistant but less responsive to stimulation for hypertrophy. This may result in reduced hypertrophic gains with partial ROM training compared to full ROM training (Schoenfeld, 2016, p. 121).
#
# References:
# McMahon, E. R., et al. (2012). Effect of knee extension length on quadriceps muscle thickness after
#
# 📚 SOURCES USED:
#
# 1. schoenfeld_rom_hypertrophy.pdf (page 121)
#    Score: 4.141
# 2. schoenfeld_rom_hypertrophy.pdf (page 122)
#    Score: 4.111
# 3. schoenfeld_rom_hypertrophy.pdf (page 127)
#    Score: 3.143
#
# ────────────────────────────────────────────────────────────────────────────────
#
# 📝 QUESTION 2
#
# Q: Should I use full ROM on all exercises?
#
# Relevant docs: ['schoenfeld_rom_hypertrophy.pdf']
# Category: rom
#
# 💬 ANSWER:
#
# Based on the provided context and scientific evidence from Brad Schoenfeld's work (2016), it is recommended to prioritize full Range of Motion (ROM) movements in a hypertrophy-oriented program.
#
# The literature suggests that training through a complete ROM can lead to greater increases in muscle thickness and cross-sectional area (Pinto et al., 581; McMahon et al., 481). A study by Bloomquist et al. (81) showed that deep squats, which involve a full ROM, promoted significant growth across the entire frontal thigh musculature.
#
# However, it is also acknowledged that integrating partial-range movements may enhance hypertrophy, particularly when used in conjunction with failure training and periodized to avoid an overtrained state (Schoenfeld, 2016, page 127).
#
# To maximize muscle adaptations, consider using full ROM on all exercises whenever possible. If a particular exercise cannot be performed with full ROM, consult with a qualified trainer or healthcare professional to determine the most effective range of motion.
#
# References:
# Bloomquist, E., et al. (81)
# McMahon, B., et al. (481)
# Pinto, L., et al. (581)
# Schoenfeld, B. J. (2016). The Mechanisms of Muscle Hyp
#
# 📚 SOURCES USED:
#
# 1. schoenfeld_rom_hypertrophy.pdf (page 127)
#    Score: 5.458
# 2. schoenfeld_rom_hypertrophy.pdf (page 121)
#    Score: 4.504
# 3. schoenfeld_rom_hypertrophy.pdf (page 122)
#    Score: 4.025
#
# ────────────────────────────────────────────────────────────────────────────────
#
# 📝 QUESTION 3
#
# Q: Should I train to failure for maximum muscle growth?
#
# Relevant docs: ['bernardez_training_variables.pdf']
# Category: volume
#
# 💬 ANSWER:
#
# Based on the context provided by Document 1 (schoenfeld_rom_hypertrophy.pdf), it appears that training to failure may not be necessary for maximum muscle growth. According to Brad Schoenfeld (2016), "there is little difference in muscle hypertrophy when training with isotonic repetition durations ranging from 0.5 to 6 seconds to muscular failure" (Page 127).
#
# However, it's essential to note that combining different repetition durations and training muscles first in a resistance training bout may enhance the hypertrophic response (Document 1). Additionally, Giessing et al. (2017) found that training to muscular failure at 80% of 1RM resulted in greater lean mass gains than using self-determined termination (Page 247).
#
# It's also crucial to consider the potential drawbacks of training to failure, such as increased risk of overtraining and psychological burnout (Izquierdo et al., 2017). A balanced approach that incorporates different repetition durations and avoids persistent failure training may be a more effective strategy for maximizing muscle growth.
#
# Therefore, I would recommend that you consult with a qualified professional or conduct further research to determine the best training protocol for your specific needs.
#
# 📚 SOURCES USED:
#
# 1. schoenfeld_rom_hypertrophy.pdf (page 127)
#    Score: 4.604
# 2. schoenfeld_rom_hypertrophy.pdf (page 124)
#    Score: 3.879
# 3. schoenfeld_rom_hypertrophy.pdf (page 126)
#    Score: 2.997
#
# ────────────────────────────────────────────────────────────────────────────────
#
# 📝 QUESTION 4
#
# Q: Is there a point where more volume stops helping muscle growth?
#
# Relevant docs: ['bernardez_training_variables.pdf']
# Category: volume
#
# 💬 ANSWER:
#
# According to Brad Schoenfeld's work (2016), research suggests that there is a point beyond which additional volume confers no additional hypertrophic benefits. The relationship between volume and hypertrophy is hypothesized to follow an inverted-U curve, where muscle accretion peaks at a given volume load and further increases in volume can actually impair muscular gains (Schoenfeld, 2016, page 81).
#
#  Studies have shown that the threshold for volume-related hypertrophic benefits varies based on genetics (Schoenfeld, 2016) and lifestyle-related factors such as nutritional status, daily stress levels, and sleep patterns (Schoenfeld, 2013). Research by Holm et al. (311) demonstrated that muscle hypertrophy is diminished when loads higher than 60% of 1RM are not carried out to a point that approaches muscular failure.
#
# In conclusion, while more volume may continue to have some benefits for muscle growth, there appears to be an optimal point beyond which additional volume confers no additional gains. The exact threshold varies among individuals and is influenced by factors such as genetics and lifestyle (Source: Schoenfeld_rom_hypertrophy.pdf, page 81).
#
# 📚 SOURCES USED:
#
# 1. schoenfeld_rom_hypertrophy.pdf (page 78)
#    Score: 1.247
# 2. bernardez_training_variables.pdf (page 6)
#    Score: -0.122
# 3. schoenfeld_rom_hypertrophy.pdf (page 92)
#    Score: -0.592
#
# ────────────────────────────────────────────────────────────────────────────────
#
# 📝 QUESTION 5
#
# Q: How many sets per exercise should I do for hypertrophy?
#
# Relevant docs: ['bernardez_training_variables.pdf']
# Category: volume
#
# 💬 ANSWER:
#
# Based on the provided context and sources, it is recommended to perform 2-3 sets per exercise for hypertrophy gains. A meta-analysis by Krieger (2010) found that performing multiple sets (2-3 sets) entails 40% more hypertrophy compared to a single set (Krieger, 2010). This study suggests that increasing the number of sets from 1 to 2 or 3 can lead to significant gains in muscle mass.
#
# Additionally, Document 1 by Bernárdez-Vázquez et al. (2022) recommends prescribing 2-3 sets per exercise, covering at least 10 weekly sets for each muscle group, which is consistent with the Krieger study.
#
# It's worth noting that Schoenfeld (2016) suggests performing 40-70 repetitions per muscle group per session, but this is more related to volume and repetition range than specific set numbers. Therefore, while volume and repetition range are important for hypertrophy, the recommended number of sets per exercise is 2-3.
#
# [Source: Krieger, D. W. (2010). Effects of resistance training on muscle thickness: a meta-analysis. Journal of Strength and Conditioning Research, 24(10), 3025-303
#
# 📚 SOURCES USED:
#
# 1. bernardez_training_variables.pdf (page 10)
#    Score: 5.201
# 2. bernardez_training_variables.pdf (page 6)
#    Score: 4.988
# 3. schoenfeld_rom_hypertrophy.pdf (page 126)
#    Score: 4.952
#
# ================================================================================
#
# ✅ Sample answers generated
#
# 👀 MANUAL INSPECTION:
#    Please review the answers above and assess:
#    - Faithfulness: Does it only use info from sources?
#    - Completeness: Does it answer the question fully?
#    - Relevance: Is it concise and useful?

# %% [markdown]
# ## 📄 STEP 6: Generate Report

# %%
# Generate report
report = f"""# 📊 RAG FITNESS - EVALUATION REPORT

Date: {datetime.now().strftime('%Y-%m-%d %H:%M')}

---

## 🎯 GOLDEN DATASET

- **Total questions**: {len(golden_dataset)}
- **In-scope questions**: {len(in_scope_questions)}
- **Categories**:
"""

for cat, count in cat_counts.items():
    report += f"  - {cat}: {count} questions\n"

report += f"""
---

## 🔍 RETRIEVER METRICS

| Metric | Score | Interpretation |
|--------|-------|----------------|
| **Recall@5** | {recall_5:.1f}% | {'✅ Excellent' if recall_5 >= 80 else '⚠️ Acceptable' if recall_5 >= 60 else '❌ Needs improvement'} |
| **MRR** | {mrr:.3f} | Average position: {1/mrr if mrr > 0 else 'N/A':.1f} |
| **Precision@5** | {precision_5:.1f}% | {precision_5:.0f}% of retrieved docs are relevant |

**Evaluation**: {len(in_scope_questions)} in-scope questions

**Interpretation**:
- Recall > 80%: ✅ Excellent
- Recall 60-80%: ⚠️ Acceptable
- Recall < 60%: ❌ Needs improvement

---

## 🤖 GENERATOR QUALITY

**Evaluation method**: Manual inspection of {len(sample_questions)} sample answers

**Note**: LLM-as-Judge with small models (Llama 3.2 3B) is not reliable.
Manual inspection is recommended for assessing:
- Faithfulness (no hallucinations)
- Completeness (answers the question fully)
- Relevance (concise and useful)

**To evaluate generator quality**:
1. Run this notebook
2. Review sample answers in Step 5
3. Rate each answer manually (1-5 scale)
4. Average scores give true quality estimate

---

## 📁 FILES

- Golden Dataset: `data/golden_dataset.json`
- Knowledge Base: `data/processed/chroma_db/`
- Evaluation Notebook: `notebooks/02_evaluate_system.ipynb`
"""

# Save report
report_path = Path.cwd().parent / "EVALUATION_REPORT.md"
with open(report_path, 'w', encoding='utf-8') as f:
    f.write(report)

print("📄 Report generated")
print(f"   Saved to: {report_path}")
print("\n" + report)
# Out:
# 📄 Report generated
#    Saved to: c:\RAG-Fitness-Test\EVALUATION_REPORT.md
#
# # 📊 RAG FITNESS - EVALUATION REPORT
#
# Date: 2025-12-23 18:37
#
# ---
#
# ## 🎯 GOLDEN DATASET
#
# - **Total questions**: 20
# - **In-scope questions**: 17
# - **Categories**:
#   - nutrition: 7 questions
#   - rom: 5 questions
#   - volume: 5 questions
#   - out_of_scope: 3 questions
#
# ---
#
# ## 🔍 RETRIEVER METRICS
#
# | Metric | Score | Interpretation |
# |--------|-------|----------------|
# | **Recall@5** | 88.2% | ✅ Excellent |
# | **MRR** | 0.776 | Average position: 1.3 |
# | **Precision@5** | 69.4% | 69% of retrieved docs are relevant |
#
# **Evaluation**: 17 in-scope questions
#
# **Interpretation**:
# - Recall > 80%: ✅ Excellent
# - Recall 60-80%: ⚠️ Acceptable
# - Recall < 60%: ❌ Needs improvement
#
# ---
#
# ## 🤖 GENERATOR QUALITY
#
# **Evaluation method**: Manual inspection of 5 sample answers
#
# **Note**: LLM-as-Judge with small models (Llama 3.2 3B) is not reliable.
# Manual inspection is recommended for assessing:
# - Faithfulness (no hallucinations)
# - Completeness (answers the question fully)
# - Relevance (concise and useful)
#
# **To evaluate generator quality**:
# 1. Run this notebook
# 2. Review sample answers in Step 5
# 3. Rate each answer manually (1-5 scale)
# 4. Average scores give true quality estimate
#
# ---
#
# ## 📁 FILES
#
# - Golden Dataset: `data/golden_dataset.json`
# - Knowledge Base: `data/processed/chroma_db/`
# - Evaluation Notebook: `notebooks/02_evaluate_system.ipynb`

# %% [markdown]
# ## ✅ EVALUATION COMPLETE
#
# **Summary:**
# - Retriever metrics calculated (Recall@5, MRR, Precision@5)
# - Sample answers generated for manual inspection
# - Report saved to `EVALUATION_REPORT.md`
#
# **Next steps:**
# 1. Review sample answers above (Step 5)
# 2. If Recall@5 < 80%, consider:
#    - Adding more diverse documents
#    - Tuning hybrid search parameters
#    - Improving chunking strategy
# 3. If answers have issues, adjust:
#    - System prompt (src/config.py)
#    - Temperature (currently 0.1)
#    - Context window (top_k)
#
# **Remember**: Manual evaluation > LLM-as-Judge for quality assessment!
